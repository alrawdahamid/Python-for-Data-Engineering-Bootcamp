# %% [markdown]
# <a href="https://colab.research.google.com/github/alrawdahamid/Python-for-Data-Engineering-Bootcamp/blob/main/strings4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s1 = s1 = "Ynm"
s2 = "PYnative"
counter = 0; #counts ocuurances of similar characters
one_char_not_found = False # turns to true if any character in s1 not found in s2
for i in range(0, len(s1)-1):
  for j in range(0, len(s2)-1):
    if s1[i] == s2[j]:
      counter+=1
  if j == len(s2)-1 and counter == 0:
    break
    one_char_not_found = True
  if one_char_not_found == True:
    break #get out of the outer loop
if one_char_not_found == False:
  print(True)
# Out:
# True
